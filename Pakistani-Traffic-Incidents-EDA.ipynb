# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Pakistani_Traffic_Accidents.csv')
data
# Out:
#    *- Islamabad Included. Unnamed: 1                 Unnamed: 2  \
# 0                     NaN        NaN                        NaN
# 1                     NaN       Year  Total number of accidents
# 2                Pakistan    2008-09                       9496
# 3                Pakistan    2009-10                       9747
# 4                Pakistan    2010-11                       9723
# ..                    ...        ...                        ...
# 59              Islamabad    2014-15                        216
# 60              Islamabad    2015-16                        244
# 61              Islamabad    2016-17                        226
# 62              Islamabad    2017-18                        259
# 63              Islamabad    2018-19                        238
#
#          Unnamed: 3           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0               NaN                  NaN        NaN        NaN
# 1   Fatal Accidents  Non-Fatal Accidents     Killed    Injured
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(5)
# Out:
#   *- Islamabad Included. Unnamed: 1                 Unnamed: 2  \
# 0                    NaN        NaN                        NaN
# 1                    NaN       Year  Total number of accidents
# 2               Pakistan    2008-09                       9496
# 3               Pakistan    2009-10                       9747
# 4               Pakistan    2010-11                       9723
#
#         Unnamed: 3           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0              NaN                  NaN        NaN        NaN
# 1  Fatal Accidents  Non-Fatal Accidents     Killed    Injured
# 2             4145                 5351       4907      11037
# 3             4378                 5369       5280      11173
# 4             4280                 5443       5271      11383
#
#                           Unnamed: 7
# 0                                NaN
# 1  Total number of vehicles involved
# 2                              10322
# 3                              10496
# ...

# %%
data.tail()
# Out:
#    *- Islamabad Included. Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 59              Islamabad    2014-15        216        107        109
# 60              Islamabad    2015-16        244        120        124
# 61              Islamabad    2016-17        226        127         99
# 62              Islamabad    2017-18        259        157        102
# 63              Islamabad    2018-19        238        127        111
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 59        118        182        217
# 60        140        209        244
# 61        129        124        216
# 62        167        162        259
# 63        136        134        239

# %%
data.shape
# Out:
# (64, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   *- Islamabad Included.  62 non-null     object
#  1   Unnamed: 1              63 non-null     object
#  2   Unnamed: 2              63 non-null     object
#  3   Unnamed: 3              63 non-null     object
#  4   Unnamed: 4              63 non-null     object
#  5   Unnamed: 5              63 non-null     object
#  6   Unnamed: 6              63 non-null     object
#  7   Unnamed: 7              63 non-null     object
# dtypes: object(8)
# memory usage: 4.1+ KB

# %%
data.shape
# Out:
# (64, 8)

# %%
data.columns
# Out:
# Index(['*- Islamabad Included.', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
data.rename(columns={'*- Islamabad Included.':'Place','Unnamed: 1':'Year','Unnamed: 2':'Total_accidents','Unnamed: 3':'Fatal_Accident','Unnamed: 4':'Non-Fatal_Accidents','Unnamed: 5':'Killed','Unnamed: 6':'Injured','Unnamed: 7':'Total_vehicles_involved'},inplace=True)

# %%
data=data.iloc[2:]
data
# Out:
#         Place        Year Total_accidents Fatal_Accident Non-Fatal_Accidents  \
# 2    Pakistan     2008-09            9496           4145                5351
# 3    Pakistan     2009-10            9747           4378                5369
# 4    Pakistan     2010-11            9723           4280                5443
# 5    Pakistan     2011-12            9140           3966                5174
# 6    Pakistan  2012-13 *             8988           3884                5104
# ..        ...         ...             ...            ...                 ...
# 59  Islamabad     2014-15             216            107                 109
# 60  Islamabad     2015-16             244            120                 124
# 61  Islamabad     2016-17             226            127                  99
# 62  Islamabad     2017-18             259            157                 102
# 63  Islamabad     2018-19             238            127                 111
#
#    Killed Injured Total_vehicles_involved
# ...

# %%
data['Year']=data['Year'].replace("2012-13 * ","2012-13")
data['Year']=data['Year'].replace("2013-14*","2013-14")
data['Year']=data['Year'].replace("2014-15*","2014-15")
data['Year']=data['Year'].replace("2015-16*","2015-16")
data['Year']=data['Year'].replace("2016-17*","2016-17")
# Out:
# C:\Users\Rizwan computer\AppData\Local\Temp\ipykernel_13244\2037518482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year']=data['Year'].replace("2012-13 * ","2012-13")
# C:\Users\Rizwan computer\AppData\Local\Temp\ipykernel_13244\2037518482.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year']=data['Year'].replace("2013-14*","2013-14")
# C:\Users\Rizwan computer\AppData\Local\Temp\ipykernel_13244\2037518482.py:3: SettingWithCopyWarning:
# ...

# %%
data['Year']=data['Year'].str.split("-").str[0]
data=data.explode('Year',ignore_index=True)
# Out:
# C:\Users\Rizwan computer\AppData\Local\Temp\ipykernel_13244\3796079608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year']=data['Year'].str.split("-").str[0]

# %%
data=data.astype({'Place':str,'Year':int,'Total_accidents':int,'Fatal_Accident':int,'Non-Fatal_Accidents':int,
                 'Killed':int,'Injured':int,'Total_vehicles_involved':int})
data
# Out:
#         Place  Year  Total_accidents  Fatal_Accident  Non-Fatal_Accidents  \
# 0    Pakistan  2008             9496            4145                 5351
# 1    Pakistan  2009             9747            4378                 5369
# 2    Pakistan  2010             9723            4280                 5443
# 3    Pakistan  2011             9140            3966                 5174
# 4    Pakistan  2012             8988            3884                 5104
# ..        ...   ...              ...             ...                  ...
# 57  Islamabad  2014              216             107                  109
# 58  Islamabad  2015              244             120                  124
# 59  Islamabad  2016              226             127                   99
# 60  Islamabad  2017              259             157                  102
# 61  Islamabad  2018              238             127                  111
#
#     Killed  Injured  Total_vehicles_involved
# ...

# %% [markdown]
# In which province the most accidents have occurred?

# %%
province=data.groupby('Place')
province
len(province)
# Out:
# 6

# %%
province.size()
# Out:
# Place
# Balochistan           11
# Islamabad              7
# Khyber Pakhtunkhwa    11
# Pakistan              11
# Punjab                11
# Sindh                 11
# dtype: int64

# %%
province['Total_accidents'].sum().sort_values(ascending=False)
# Out:
# Place
# Pakistan              103900
# Punjab                 49354
# Khyber Pakhtunkhwa     37237
# Sindh                  11607
# Balochistan             4062
# Islamabad               1640
# Name: Total_accidents, dtype: int32

# %% [markdown]
# In which province the least accidents have occurred?

# %%
province['Total_accidents'].sum().sort_values(ascending=True)
# Out:
# Place
# Islamabad               1640
# Balochistan             4062
# Sindh                  11607
# Khyber Pakhtunkhwa     37237
# Punjab                 49354
# Pakistan              103900
# Name: Total_accidents, dtype: int32

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")

slices = [49354,37237,11607,4062,1640]
labels = ['Punjab  ', 'Khyber Pakhtunkhwa ', 'Sindh ', 'Balochistan','Islamabad ']
colors = ['yellow', 'pink', 'purple', 'hotpink','brown']
explode = [0, 0, 0.1, 0, 0]

plt.pie(slices, labels = labels, colors = colors, explode=explode, shadow=True,startangle=180, wedgeprops={'edgecolor':'black'})
plt.title("TOTAL ACCIDENTS IN EACH PROVINCE")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(data['Total_accidents'])
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total_accidents'>

# %%
sns.violinplot(data['Total_accidents'])
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total_accidents'>

# %% [markdown]
# In which province most people were killed?

# %%
province['Killed'].sum().sort_values(ascending=False)
# Out:
# Place
# Pakistan              54612
# Punjab                29978
# Khyber Pakhtunkhwa    12104
# Sindh                  8995
# Balochistan            2604
# Islamabad               931
# Name: Killed, dtype: int32

# %% [markdown]
# In which province least people were killed?

# %%
province['Killed'].sum().sort_values(ascending=True)
# Out:
# Place
# Islamabad               931
# Balochistan            2604
# Sindh                  8995
# Khyber Pakhtunkhwa    12104
# Punjab                29978
# Pakistan              54612
# Name: Killed, dtype: int32

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")

slices = [29978,12104,8995, 2604,931]
labels = ['Punjab  ', 'Khyber Pakhtunkhwa ', 'Sindh ', 'Balochistan','Islamabad ']
colors = ['yellow', 'pink', 'purple', 'hotpink','brown']
explode = [0, 0, 0.1, 0, 0]

plt.pie(slices, labels = labels, colors = colors, explode=explode, shadow=True,startangle=180, wedgeprops={'edgecolor':'black'})
plt.title("RATIO OF KILLED PEOPLE IN EACH PROVINCE")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(data['Killed'])
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Killed'>

# %%
sns.violinplot(data['Killed'])
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Killed'>

# %% [markdown]
# In which province most people were injured?

# %%
province['Injured'].sum().sort_values(ascending=False)
# Out:
# Place
# Pakistan              124834
# Punjab                 57103
# Khyber Pakhtunkhwa     50985
# Sindh                   9957
# Balochistan             5592
# Islamabad               1197
# Name: Injured, dtype: int32

# %% [markdown]
# In which province least people were injured?

# %%
province['Injured'].sum().sort_values(ascending=True)
# Out:
# Place
# Islamabad               1197
# Balochistan             5592
# Sindh                   9957
# Khyber Pakhtunkhwa     50985
# Punjab                 57103
# Pakistan              124834
# Name: Injured, dtype: int32

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")

slices = [ 57103,50985,9957, 5592,1197]
labels = ['Punjab  ', 'Khyber Pakhtunkhwa ', 'Sindh ', 'Balochistan','Islamabad ']
colors = ['yellow', 'pink', 'purple', 'hotpink','brown']
explode = [0, 0, 0.1, 0, 0]

plt.pie(slices, labels = labels, colors = colors, explode=explode, shadow=True,startangle=180, wedgeprops={'edgecolor':'black'})
plt.title("RATIO OF INJURED PEOPLE IN EACH PROVINCE")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(data['Injured'])
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Injured'>

# %%
sns.violinplot(data['Injured'])
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Injured'>

# %% [markdown]
# In which year most accident has occurred?

# %%
Years=data.groupby('Year')
Years
len(Years)
# Out:
# 11

# %%
Years.size()
# Out:
# Year
# 2008    5
# 2009    5
# 2010    5
# 2011    5
# 2012    6
# 2013    6
# 2014    6
# 2015    6
# 2016    6
# 2017    6
# 2018    6
# dtype: int64

# %%
Years['Total_accidents'].sum().sort_values(ascending=False)
# Out:
# Year
# 2017    22242
# 2018    21558
# 2009    19494
# 2010    19446
# 2016    19164
# 2008    18992
# 2011    18280
# 2015    18200
# 2012    17976
# 2013    16718
# 2014    15730
# Name: Total_accidents, dtype: int32

# %% [markdown]
# In which year least accident has occurred?

# %%
Years['Total_accidents'].sum().sort_values(ascending=True)
# Out:
# Year
# 2014    15730
# 2013    16718
# 2012    17976
# 2015    18200
# 2011    18280
# 2008    18992
# 2016    19164
# 2010    19446
# 2009    19494
# 2018    21558
# 2017    22242
# Name: Total_accidents, dtype: int32

# %%
sns.relplot(x='Total_accidents', y = 'Fatal_Accident', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Total_accidents', y = 'Total_vehicles_involved', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Fatal_Accident', y = 'Killed', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Fatal_Accident', y = 'Injured', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Non-Fatal_Accidents', y = 'Killed', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Non-Fatal_Accidents', y = 'Injured', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Fatal_Accident', y = 'Total_vehicles_involved', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.relplot(x='Non-Fatal_Accidents', y = 'Total_vehicles_involved', kind = 'scatter',hue = 'Place', data=data)

# %%
sns.catplot(x ='Non-Fatal_Accidents', y = 'Place', kind = 'strip', data = data)

# %%
sns.catplot(x ='Fatal_Accident', y = 'Place', kind = 'strip', data = data)

# %%
sns.catplot(x ='Total_accidents', y = 'Place', kind = 'swarm', data = data)
# Out:
# c:\Users\Rizwan computer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 27.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x ='Total_accidents', y = 'Place', data = data)
# Out:
# <AxesSubplot:xlabel='Total_accidents', ylabel='Place'>

# %%
sns.catplot(x = 'Total_accidents', y = 'Place', kind = 'box', data = data)

# %%
sns.catplot(x = 'Total_vehicles_involved', y = 'Place', kind = 'box', data = data)

# %%
sns.catplot(x = 'Year', y = 'Total_accidents', kind = 'bar', data = data)
